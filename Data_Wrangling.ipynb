# %% [markdown]
# # Pre-Processing Data in Python with `pandas`
# * The process of preparing data for analysis is referred to as **data cleaning** or **data wrangling**.
# * Data wrangling involves:
#     * **Data cleaning**: removing and/or correcting bad data.
#     * **Data tidying**: restructuring data to facilitate analysis.
# * In this lesson, we will focus on data cleaning.

# %% [markdown]
# 1. [Importing Data](Importing-and-Exporting-Data)
# 2. [Handling Missing Values](#2.-Handling-Missing-Values)
# 3. [Handling Duplicates](#3.-Handling-Duplicates)
# 4. [Handling Outliers](#4.-Handling-Outliers)
# 5. [Handling Data Types](#5.-Handling-Data-Types)
# 6. [Handling Dates and Times](#6.-Handling-Dates-and-Times)
# 7. [Handling Text](#7.-Handling-Text)
# 8. [Handling Categorical Variables](#8.-Handling-Categorical-Variables)
# 9. [Handling Sparse Data](#9.-Handling-Sparse-Data)
# 10. [Handling Big Data](#10.-Handling-Big-Data)
# 11. [Handling Data in Other Formats](#11.-Handling-Data-in-Other-Formats)
# 12. [Handling Data from Relational Databases](#12.-Handling-Data-from-Relational-Databases)
# 13. [Handling Data from Non-Relational Databases](#13.-Handling-Data-from-Non-Relational-Databases)
# 14. [Handling Data from the Web](#14.-Handling-Data-from-the-Web)
# 15. [Handling Data from APIs](#15.-Handling-Data-from-APIs)
# 16. [Handling Data from Spreadsheets](#16.-Handling-Data-from-Spreadsheets)
# 17. [Handling Data from Microsoft Excel](#17.-Handling-Data-from-Microsoft-Excel)
# 18. [Handling Data from SAS](#18.-Handling-Data-from-SAS)
# 19. [Handling Data from Stata](#19.-Handling-Data-from-Stata)
# 20. [Handling Data from HDF5](#20.-Handling-Data-from-HDF5)
# 21. [Handling Data from MATLAB](#21.-Handling-Data-from-MATLAB)
# 22. [Handling Data from Google BigQuery](#22.-Handling-Data-from-Google-BigQuery)
# 23. [Handling Data from Feather](#23.-Handling-Data-from-Feather)
# 24. [Handling Data from Parquet](#24.-Handling-Data-from-Parquet)
# 25. [Handling Data from ORC](#25.-Handling-Data-from-ORC)
# 26. [Handling Data from SQL](#26.-Handling-Data-from-SQL)
# 27. [Handling Data from Google Sheets](#27.-Handling-Data-from-Google-Sheets)
# 28. [Handling Data from JSON](#28.-Handling-Data-from-JSON)
# 29. [Handling Data from Pickle](#29.-Handling-Data-from-Pickle)
# 30. [Handling Data from Clipboard](#30.-Handling-Data-from-Clipboard)
# 31. [Handling Data from Python Objects](#31.-Handling-Data-from-Python-Objects)
# 32. [Handling Data from Other Sources](#32.-Handling-Data-from-Other-Sources)

# %% [markdown]
# ## 1. Importing and Exporting Data
# * Also known as **reading or writing data** or **Data Acquisition**.
# * Data Acquisition is the process of loading and reading data into noebook from various sources.
# * Data Acquisition is the first step in the data analysis process.
# * Data can be stored in various formats:
#     * CSV: Comma Separated Values
#     * Excel: Microsoft Excel
#     * JSON: JavaScript Object Notation
#     * HTML: HyperText Markup Language
#     * SQL: Structured Query Language
#     * SAS: Statistical Analysis System
#     * Stata: Stata
#     * HDF5: Hierarchical Data Format
#     * MATLAB: MATrix LABoratory
#     * Google BigQuery: Google BigQuery
#     * Feather: Feather
#     * Parquet: Parquet
#     * ORC: Optimized Row Columnar
#     * Clipboard: Clipboard
#     * Pickle: Pickle
#     * Python Objects: Python Objects
#     * Other Sources: Like APIs, Web, etc.
#
# * To read any data using Python's pandas library, there are two important factors to consider:
#     * The data format: Way in which the data is stored.
#     * The data source: Location of the data.
# * In pandas, we use the `read_` family of functions to read data into a DataFrame.
# * Reading data into a DataFrame is a two step process:
#     * Step 1: Import the pandas library.
#     * Step 2: Then define a variable with thid file path and name.
#     * Step 3: Use the `read_` function to read the data into a DataFrame.
#
# * Exporting data from a DataFrame is a two step process:
#     * Step 1: Define a variable with the file path and name.
#     * Step 2: Use the `to_` function to export the data from a DataFrame.

# %%
# Step 1: Importing the libraries
import pandas as pd

# %%
# Step 2: Setting path of the dataset
url = "Data/automobile.csv"

# %%
# Step 3: Importing the dataset
df = pd.read_csv(url)

# %%
# Step 4: Printing the dataset
print(df)
# Out:
#      Unnamed: 0  symboling normalized-losses         make fuel-type
# 0             0          3                 ?  alfa-romero       gas  \
# 1             1          3                 ?  alfa-romero       gas
# 2             2          1                 ?  alfa-romero       gas
# 3             3          2               164         audi       gas
# 4             4          2               164         audi       gas
# ..          ...        ...               ...          ...       ...
# 200         200         -1                95        volvo       gas
# 201         201         -1                95        volvo       gas
# 202         202         -1                95        volvo       gas
# 203         203         -1                95        volvo    diesel
# 204         204         -1                95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  ...
# ...

# %%
# Step 5: Printing the first 5 rows of the dataset
# head() function in pandas is used to print the first 5 rows of the dataset
print(df.head())
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type aspiration
# 0           0          3                 ?  alfa-romero       gas        std  \
# 1           1          3                 ?  alfa-romero       gas        std
# 2           2          1                 ?  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  ...  engine-size
# 0          two  convertible          rwd           front  ...          130  \
# 1          two  convertible          rwd           front  ...          130
# 2          two    hatchback          rwd           front  ...          152
# 3         four        sedan          fwd           front  ...          109
# 4         four        sedan          4wd           front  ...          136
#
# ...

# %%
# We can only write df.head() to print the first 5 rows of the dataset
df.head()
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type aspiration
# 0           0          3                 ?  alfa-romero       gas        std  \
# 1           1          3                 ?  alfa-romero       gas        std
# 2           2          1                 ?  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  ...  engine-size
# 0          two  convertible          rwd           front  ...          130  \
# 1          two  convertible          rwd           front  ...          130
# 2          two    hatchback          rwd           front  ...          152
# 3         four        sedan          fwd           front  ...          109
# 4         four        sedan          4wd           front  ...          136
#
# ...

# %%
# To export the dataset to csv file use to_csv() function
#df.to_csv('Data/automobile2.csv')

# %% [markdown]
# # Basic insights from the data
# * `df.head()` - Returns the first 5 rows of the DataFrame.
# * `df.tail()` - Returns the last 5 rows of the DataFrame.
# * `df.shape` - Returns the number of rows and columns of the DataFrame.
# * `df.info()` - Returns the data type and memory information of the DataFrame.
# * `df.describe()` - Returns the summary statistics of the DataFrame.
# * `df.columns` - Returns the column names of the DataFrame.
# * `df.index` - Returns the index of the DataFrame.
# * `df.values` - Returns the values of the DataFrame.
# * `df.dtypes` - Returns the data type of each column of the DataFrame.
# * `df.memory_usage()` - Returns the memory usage of each column of the DataFrame.
# * `df.count()` - Returns the number of non-null values in each DataFrame column.
# * `df.max()` - Returns the highest value in each column of the DataFrame.
# * `df.min()` - Returns the lowest value in each column of the DataFrame.
# * `df.mean()` - Returns the mean value in each column of the DataFrame.
# * `df.median()` - Returns the median value in each column of the DataFrame.
# * `df.std()` - Returns the standard deviation of each column of the DataFrame.
# * `df.sum()` - Returns the sum of all values in each column of the DataFrame.
# * `df.nunique()` - Returns the number of unique values in each column of the DataFrame.
# * `df.unique()` - Returns the unique values in each column of the DataFrame.
# * `df.isnull()` - Returns a DataFrame of booleans that indicates whether a value is missing or not.
# * `df.notnull()` - Returns a DataFrame of booleans that indicates whether a value is not missing or not.
# * `df.dropna()` - Returns a DataFrame with rows that do not contain any missing values.
# * `df.fillna()` - Returns a DataFrame with missing values filled or imputed.
# * `df.sample()` - Returns a random sample of rows from the DataFrame.
# * `df.sample(frac=0.5)` - Returns a random sample of 50% of the rows from the DataFrame.
# * `df.sample(n=10)` - Returns a random sample of 10 rows from the DataFrame.
# * `df.sample(n=10, random_state=42)` - Returns a random sample of 10 rows from the DataFrame using a random seed of 42.
# * `df.sample(frac=0.5, replace=True)` - Returns a random sample of 50% of the rows from the DataFrame with replacement.
# * `df.sample(n=10, axis=1)` - Returns a random sample of 10 columns from the DataFrame.
# * `df.sample(n=10, axis='columns')` - Returns a random sample of 10 columns from the DataFrame.
# * `df.sample(n=10, axis='columns', random_state=42)` - Returns a random sample of 10 columns from the DataFrame using a random seed of 42.
# * `df.drop_duplicates()` - Returns a DataFrame with duplicate rows removed, by default it removes duplicate rows based on all columns.
# * `df.drop_duplicates(subset=['col1'])` - Returns a DataFrame with duplicate rows removed based on the column `col1`.
# * `df.drop_duplicates(subset=['col1', 'col2'])` - Returns a DataFrame with duplicate rows removed based on the columns `col1` and `col2`.
# * `df.drop_duplicates(keep='last')` - Returns a DataFrame with duplicate rows removed and keeps the last occurence.
# * `df.drop_duplicates(keep=False)` - Returns a DataFrame with duplicate rows removed and keeps none of the occurences.
# * `df.drop_duplicates(inplace=True)` - Returns a DataFrame with duplicate rows removed and updates the existing DataFrame.
# * `df.drop_duplicates(subset=['col1'], inplace=True)` - Returns a DataFrame with duplicate rows removed based on the column `col1` and updates the existing DataFrame.
# * `df.drop_duplicates(subset=['col1', 'col2'], inplace=True)` - Returns a DataFrame with duplicate rows removed based on the columns `col1` and `col2` and updates the existing DataFrame.
# * `df.drop_duplicates(subset=['col1'], keep='last', inplace=True)` - Returns a DataFrame with duplicate rows removed based on the column `col1` and keeps the last occurence and updates the existing DataFrame.
# * `df.drop_duplicates(subset=['col1', 'col2'], keep=False, inplace=True)` - Returns a DataFrame with duplicate rows removed based on the columns `col1` and `col2` and keeps none of the occurences and updates the existing DataFrame.
# * `df.drop_duplicates(subset=['col1'], keep=False, inplace=True)` - Returns a DataFrame with duplicate rows removed based on the column `col1` and keeps none of the occurences and updates the existing DataFrame.

# %% [markdown]
# * Understand your data before you begin an analysis.
# * Should check:
#     * Data Types
#     * Data Distribution
# * Locate potential issues with the data
#
# * `Pandas Type` - `Python Type`     - `NumPy Type`              - `Usage`
# * `object`      - `str` or mixed    - `string_` or `unicode_`   - Text or mixed numeric and non-numeric values
# * `int64`       - `int`             - `int_`                    - Integer numbers
# * `float64`     - `float`           - `float_`                  - Floating point numbers
# * `bool`        - `bool`            - `bool_`                   - True/False values
# * `datetime64`  - `datetime`        - `datetime64`              - Date and time values
# * `timedelta[ns]` - `NA`            - `NA`                      - Differences between two datetimes
# * `category`    - `NA`              - `NA`                      - Finite list of text values

# %% [markdown]
# # Why check Data Types?
# * potential info and type mismatches
# * compatibility with python methods
#
# In pandas we use dataframe.dtypes to check the data types of each column in the dataframe.

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# * Now we would like to check the statistical summary of each column to learn about the distribution of data in each column. We can do this using dataframe.describe().
#
# * The statistical metrices can tell the data scientist if there are mathematical issues that maey exist, such as extreme outliers and large deviations.

# %%
df.describe()
# Out:
#        Unnamed: 0   symboling  wheel-base      length       width      height
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000  \
# mean   102.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      0.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     51.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    102.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    153.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    204.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# ...

# %% [markdown]
# # `df.describe()` - Returns the summary statistics of the DataFrame.
# * `count` - Number of non-null observations
# * `mean` - Mean of values
# * `std` - Standard deviation of observations
# * `min` - Minimum observation
# * `25%` - 25th percentile
# * `50%` - 50th percentile
# * `75%` - 75th percentile
# * `max` - Maximum observation

# %% [markdown]
# By `default` dataframe.describe() returns the summary statistics of the numeric columns in the dataframe. To enable a summary of all the columns in the dataframe, we can use the argument `include='all'`.

# %%
df.describe(include = "all")
# Out:
#         Unnamed: 0   symboling normalized-losses    make fuel-type aspiration
# count   205.000000  205.000000               205     205       205        205  \
# unique         NaN         NaN                52      22         2          2
# top            NaN         NaN                 ?  toyota       gas        std
# freq           NaN         NaN                41      32       185        168
# mean    102.000000    0.834146               NaN     NaN       NaN        NaN
# std      59.322565    1.245307               NaN     NaN       NaN        NaN
# min       0.000000   -2.000000               NaN     NaN       NaN        NaN
# 25%      51.000000    0.000000               NaN     NaN       NaN        NaN
# 50%     102.000000    1.000000               NaN     NaN       NaN        NaN
# 75%     153.000000    2.000000               NaN     NaN       NaN        NaN
# max     204.000000    3.000000               NaN     NaN       NaN        NaN
#
# ...

# %% [markdown]
# We can see that for object-type columns, a different set of statistics is evaluated. The `unique` count is the number of unique values in the column. The `top` is the most frequently occurring value. The `freq` is the number of times the top value occurs.
#
# * `NaN` - Not a Number

# %%
# Another method we canuse to check our dataset is info() function
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         205 non-null    int64
#  1   symboling          205 non-null    int64
#  2   normalized-losses  205 non-null    object
#  3   make               205 non-null    object
#  4   fuel-type          205 non-null    object
#  5   aspiration         205 non-null    object
#  6   num-of-doors       205 non-null    object
#  7   body-style         205 non-null    object
#  8   drive-wheels       205 non-null    object
#  9   engine-location    205 non-null    object
#  10  wheel-base         205 non-null    float64
#  11  length             205 non-null    float64
#  12  width              205 non-null    float64
#  13  height             205 non-null    float64
#  14  curb-weight        205 non-null    int64
#  15  engine-type        205 non-null    object
# ...

# %% [markdown]
# # Data Wrangling
# * Data wrangling is the process of cleaning, structuring and enriching raw data into a desired format for better decision making in less time.
# ## Pre-Processing Data in Python with `pandas`
# * The process of converting or mapping data from the initial `raw` form into another format, in order to prepare the data for further analysis.
# * Also known as
#     1. Data Cleaning
#     2. Data Wrangling
#
# ### Dealing with Missing Values
# * When no data values is stored for a feature for a particular observation, it is known as a `missing value`.
# * Missing values are represented as `NaN`, `None`, `?`, `N/A`, `0` or just a `Blank Cell`.
#
# #### How to deal with Missing values?
# There are typical options we can consider:
# 1. The first is to check if the person or group that collected the data can go back and find what the actual value should be.
# 2. Another possibility is just to remove the data where the value is missing. This is known as `listwise deletion` or `case deletion`.
#
# #### Drop the missing values.
# * Drop the variables
# * Drop the data entry
#
# If we don't have a lot of observation with missing data, usually dropping the particular entry is the best.

# %%
# To drop missing values in python we use dropna() function. 
# By default, it drops rows with missing values.
# To drop columns, we need to provide axis=1 as an argument to the dropna() function.
df.dropna(subset=["price"], axis=0, inplace=True)
# Setting the argument inplace=True allows us to update the dataset df.

# %% [markdown]
# #### Replace the missing values.
# * If we are removing the data entry, we are losing the information for the other variables in that entry.
# * Replacing data is the better, since no data is wasted.
# * It is less accurate since we need to make assumptions about the data.
# Replace the missing values with:
# 1. Mean or average
# 2. Frequency
# 3. Other functions

# %%
# To replace missing values in python we use replace() function.
# dataFrame.replace(missing_value, new_value)
# missing_value: the value we want to replace
# new_value: the new value we want to replace with
# We can use mean, median or mode to replace missing values.
# We can also use .mean(), .median() or .mode() functions to calculate the mean, median or mode of the column.
import numpy as np
df.replace('?', np.nan, inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type aspiration
# 0           0          3               NaN  alfa-romero       gas        std  \
# 1           1          3               NaN  alfa-romero       gas        std
# 2           2          1               NaN  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  ...  engine-size
# 0          two  convertible          rwd           front  ...          130  \
# 1          two  convertible          rwd           front  ...          130
# 2          two    hatchback          rwd           front  ...          152
# 3         four        sedan          fwd           front  ...          109
# 4         four        sedan          4wd           front  ...          136
#
# ...

# %%
mean = df["normalized-losses"].astype(float).mean(axis=0)

# %%
df["normalized-losses"].replace(np.nan, mean, inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type aspiration
# 0           0          3             122.0  alfa-romero       gas        std  \
# 1           1          3             122.0  alfa-romero       gas        std
# 2           2          1             122.0  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  ...  engine-size
# 0          two  convertible          rwd           front  ...          130  \
# 1          two  convertible          rwd           front  ...          130
# 2          two    hatchback          rwd           front  ...          152
# 3         four        sedan          fwd           front  ...          109
# 4         four        sedan          4wd           front  ...          136
#
# ...

# %% [markdown]
# # Data formatting in python
# * Data are usually collected from different places in different formats.
# * Bringing data into a common standard of expression allows users to make meaningful comparison.
# * For example, people may use different expression to represent New York.
#     * N.Y.
#     * Ny
#     * NY
#     * New York

# %%
# Applying calculations to an entire column
# Convert "mpg" to "L/100km" in our dataset
df['city-mpg'] = 235/df['city-mpg']

# %%
# Rename the column using rename function
df.rename(columns={'city-mpg':'city-L/100Km'}, inplace=True)

# %% [markdown]
# * For a number of reasons, including when you import a dataset into Python, the `data type` may be incorrectly established.
# * It is important for later analysis to explore the features data type and convert them to the `correct data type`, otherwise the developed models later may behave strangely and totally valid data may be treated as missing data.

# %% [markdown]
# # Correcting Data Types
# * `df.dtypes` - Returns the data type of each column of the DataFrame.
# * `df.astype()` - Returns a copy of the DataFrame with the specified data type.

# %%
df['price'] = df['price'].astype('float')

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-L/100Km         float64
# highway-mpg            int64
# price                float64
# dtype: object

# %% [markdown]
# # Data Notmalization in Python
# Sometimes during analysis due to large difference in the ranges of two columns in a dataset, the higher range columns intrinsically influence the result more, due to its larger value, but this doesn't necessarily mean that it is more important as a predictor. So we normalize the data to bring all the columns to a more similar range.
#
# * There are several ways to normalize data:
#     * Simple Feature Scaling: Just divide each value by the maximum value for that feature.
#     * Min-Max: Takes each value, x-old, substracted from the minimum value of that feature, and then divide by the range of that feature.
#     * Z-Score: In this formula, for each calue, we sustract Mu which is the average of all the values, and then divide by the standard deviation (Sigma) of all the values.
#     * Decimal Scaling
#     * Softmax

# %%
# Simple Feature Scaling
df['length'] = df['length']/df['length'].max()

# %%
# Min-Max Scaling
#df['length'] = (df['length']-df['length'].min())/(df['length'].max()-df['length'].min())
# z-score Normalization
#df['length'] = (df['length']-df['length'].mean())/df['length'].std()
# Decimal Scaling
#df['length'] = df['length']/10**np.ceil(np.log10(df['length'].abs().max()))
# Softmax function
#df['length'] = np.exp(df['length'])/sum(np.exp(df['length']))

# %% [markdown]
# # Binning in Python
# * Binning: Grouping of values into "bins.
# * Converts numeric into categorical variables.
# * Groups a set of numerical values into a set of "bins".
# * Binning is good for:
#     * Comparing groups of data
#     * Identifying trends
#     * Identifying outliers
# * Binning can be used to:
#     * Smoothing
#     * Aggregating
#     * Visualizing
# * Binning Methods:
#     * Equal Width Binning
#     * Equal Frequency Binning
# * Something, binning can improve accuracy of the predictive models.
# * Something, we use data binning to group a set of numerical values into a set of bins to have a better understanding of the data distribution.
# * In Python, we can easily implement binning:
#     * We would like 3 bins of equal binwidth, so we need 4 numbers as dividers that are equal distance apart.
#     * First, we use the numpy function `linspace` to return the array "bins" that contains 4 equally spaced numbers over the specified interval of the price.
#     * We create a `list` named `group_names` that contains the different bin names.
#     * We use pandas function `cut` to segment and sort the data values into bins.

# %%
bins = np.linspace(min(df["price"]), max(df["price"]), 4)
group_names = ['Low', 'Medium', 'High']
df['price-binned'] = pd.cut(df['price'], bins, labels=group_names, include_lowest=True)

# %% [markdown]
# # Turning categorical variables into quantitative variables in python
# ## Categorical Variables
# * Most statistical models cannot take in the objects/string as input
# * We encode the values `by adding new features` corresponding to `each unique element in the original features` we would like to encode.
# * When a value occurs in the original features we set the corresponding value to `one` in the new feature, the rest feature are set to `zero`.
# * This technique is often called `One-Hot Encoding`.
# * In Pandas we can use `get_dummies()` method to convert categorical values to dummy variables.
# * The `get_dummies()` method automatically generates a list of numbers, each one corresponding to a particular category of the variable.

# %%
pd.get_dummies(df['fuel-type'])
# Out:
#      diesel    gas
# 0     False   True
# 1     False   True
# 2     False   True
# 3     False   True
# 4     False   True
# ..      ...    ...
# 200   False   True
# 201   False   True
# 202   False   True
# 203    True  False
# 204   False   True
#
# [205 rows x 2 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)
# It is an approach to analyze data in order to:
# 1. summarize main charateristics of the data to gain better understanding of the dataset.
# 2. uncover relationships between different variables
# 3. extract important variables for the problems we are trying to solve.

# %% [markdown]
# # 1. Descriptive Statistics
# * Describe basic features of data
# * Giving short summaries about the sample and measures of the data.
# * One way in which we can do this is by using the `describe()` method in pandas.
# * Using the `describe()` function and applying it, automatically computes basic statistics for all numerical variables.
# * Any NaN vaules are automatically skipped in these statistics.
# * for categorical values, one way we can summarize it is by using the function `value_counts()`.

# %%
drive_wheels_counts = df['drive-wheels'].value_counts()
drive_wheels_counts
# Out:
# drive-wheels
# fwd    120
# rwd     76
# 4wd      9
# Name: count, dtype: int64

# %% [markdown]
# * `Box plot` are a great way to visualize numeric data since we can visualize the various distribution of the data.
# * The main feature that the box plot shows are:
#     1. The `median` of the data, which represents where the middle datapoint is.
#     2. The `upper-quartile` shows where the 75th percentile is.
#     3. The `lower quartile` shows where the 25th percentile is.
#     4. Next we have the `lower-extremes` and `upper-extremes`. These are calculated as 1.5 times the inter-quartile range (IQR) above and below `75th` and `25th` percentile respectively.
#     5. Finally `box plots` also display `outliers` as individulal dots that occurs outside the upper and lower extremes.

# %%
import seaborn as sns
sns.boxplot(x = 'drive-wheels', y = 'price', data = df)
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %% [markdown]
# We can see that the distribution of price between the rwd (rear-wheel drive) and fwd (forward-wheel drive) and othe categories are distinct, but the price for fwd (forward-wheel drive) are almost indistinguishable.

# %% [markdown]
# * Often times we tend to see continuous variables in our data. These data points are numbers contained in some range.
# * For example:
#     1. In out dataset, price and enigne-size are continuous variables. What if we want to know what the distribution the relationship between these two columns?
#     2. One way to visualize this is by using `scatter plots`.
#     3. Each observation in a scatter plot is represented as a point.
#     4. This plot shows the relationship between two variables:
#         * The `predictor variable` is plotted on the `x-axis`.
#         * The `target variable` is plotted on the `y-axis`.
#     5. In a scatter plot, we typically set the predictor variable on the x-axis or horizontal axis and we set the target variable on the y-axis or vertical axis.
#     * We are using the Matplotlib functioon `scatter()` using taking in x and a y variables.

# %%
import matplotlib.pyplot as plt
plt.scatter(df['engine-size'], df['price'], color='red')
plt.title('Scatterplot of Engine Size vs Price') # Add a title to the scatterplot
plt.xlabel('Engine Size') # Add x-label to the scatterplot
plt.ylabel('Price') # Add y-label to the scatterplot
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# # Group By Data In Python
# ## Grouping Data
# * Assume we want to know:
#     1. Is there any relationship between tehe differnt types of `drive-system`.
#     2. If so, which type of `drive-system` adds the most value to a vehicle.
#
# * It would be nice if we could group all data by the different types of drive wheels, and compare the results of these different drive wheels against each other.
# * In pandas this can be done using `group-by()` method.
# * The `group-by()` method is used on categorical variables, groups the data into subset according to the different categories of that variables.

# %%
df_test = df[['drive-wheels', 'body-style', 'price']] #pick out the values we are interested in
df_grp = df_test.groupby(['drive-wheels', 'body-style'], as_index=False).mean() #we group the reduced data accroding to the 'drive-wheel' and'body-style'
#Since we are interested in knowing, how the average price differs accross he boards, we can take the maen of each group and append this bit at the very ed of the above line.
df_grp
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %% [markdown]
# * We can see that according to our data, `rear-wheel-drive` `convertible` and `rear-wheel-drive` `hardtop` have the highest value, while the `four-wheel-drive` `hatchbacks` have the lowest.
# * A table of ths form isn't the easiest to read, and also not very easy to visualize.
# * To make it easier to understand, we can convert this table into a `pivot table` using `pivot()` method.
# * A `pivot table` is like an Excel spreadsheet, with one variable along the column and another along the row.

# %%
df_pivot = df_grp.pivot(index='drive-wheels', columns='body-style') #we can convert the above table into a pivot table
df_pivot
# Out:
#                    price
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333  \
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# * The price data now becoms the rectangular grid which is easier to understand.
# * Another way to represent the `pivot table` is by using `heat map` which puts different colors in the cells to represent the value.
# * `HeatMap` takes a rectangular grid of data and assigns a color intensity based on the data value at the grid points.
# * It is a great way to plot the target variable over multiple variables and through this get visual clues of the relationship between these variables and the target.

# %%
plt.pcolor(df_pivot, cmap='RdBu')
plt.colorbar()
plt.show()

# %% [markdown]
# # Analysis of Variance (ANOVA)
# * Assume, that we want to anlysze a categorical variable and see the correlation among different categories.
# * To analyze categorical variabele such the `make` variable, we can use a method such as `ANOVA` method.
# * `ANOVA` is a statistical method used to test whether there are significant differences between the means of two or more groups.
# * `ANOVA` can be used to find the correlation between different groups of a categorical variable.
# * The `ANOVA` test returns two values:
#     1. `F-test score`: ANOVA assumes the means of all groups are the same, calculates how much the actual means deviate from the assumption, and reports it as the F-test score. A larger score means there is a larger difference between the means.
#     2. `P-value`: P-value tells how statistically significant is our calculated score value.
# * To implement `ANOVA` test:
#     1. First we extract the `make` and `price` data.
#     2. Then we will group the data by different makes.
#     3. The `ANOVA` test can be performed in python usig the `f_oneway()` function in the `stats` module in the `scipy` library.
#     4. The `f_oneway()` function takes the groups we want to compare as input and returns `F-test score` and `P-value`.
#     5. We then pass in the data of the two car make groups we want to compare and it calculates the `ANOVA` results.
#     5. If the `P-value` is less than a certain `significance level` (in this case 0.05), we can reject the null hypothesis and say that the `alternative hypothesis` is true.
#     6. If the `P-value` is larger than the `significance level`, we can accept the null hypothesis and say that `null hypothesis` is true.
#     7. If we get a large `F-test score` and a small `P-value`, we can reject the null hypothesis and say that the `alternative hypothesis` is true.
#     8. If we get a small `F-test score` and a large `P-value`, we cannot reject the null hypothesis and cannot say that the `alternative hypothesis` is true.

# %%
from scipy import stats
df_anova = df[['make', 'price']]
grouped_anova = df_anova.groupby(['make'])
anova_results_1 = stats.f_oneway(grouped_anova.get_group('honda')['price'], grouped_anova.get_group('subaru')['price'])
anova_results_2 = stats.f_oneway(grouped_anova.get_group('honda')['price'], grouped_anova.get_group('jaguar')['price'])

# %%
print(f"Anova result: {anova_results_1}")
print(f"Anova Result: {anova_results_2}")
# Out:
# Anova result: F_onewayResult(statistic=0.19744030127462606, pvalue=0.6609478240622193)
# Anova Result: F_onewayResult(statistic=400.925870564337, pvalue=1.0586193512077865e-11)

# %% [markdown]
# The results confirm what we guessed at first. The price between `honda` and `subaru` is not significantly different, while the price between `jaguar` and `honda` or `jaguar` and `subaru` is significantly different.
# * All in all, we can say that there is a strong correlation between a categorical variable and other variables if `ANOVA` test gives us a large `F-test` value and a small `P-value`.

# %% [markdown]
# # Correlation
# * `Correation` is a statistical metric for measuring to what extent different variables are interdependent.
# * It is important to know that `correlation` doesn't imply `causation`.
# * In other words, `Correlation` is a measure of how two variables change together, but it doesn't tell us about the cause and effect relationship between the two variables.
# * To see the coorelation we will visulaize it using `scatter plot` and add a linear line called a `regression line` between them.

# %%
sns.regplot(x='engine-size', y='price', data=df)
plt.ylim(0,)
# Out:
# (0.0, 53408.79022833078)

# %% [markdown]
# We can see that the straight line through the data points is very steep, which shows that there is a strong positive correlation between `engine-size` and `price`.

# %%
sns.regplot(x='highway-mpg', y='price', data=df)
plt.ylim(0,)
# Out:
# (0.0, 48180.38042293943)

# %% [markdown]
# As we cn see in this plot, when `highway-mpg` goes up, the `price` goes down, and when `highway-mpg` goes down, the `price` goes up. This indicates an `inverse/negative relationship` between these two variables. `Highway-mpg` could potentially be a predictor of `price`.

# %% [markdown]
# # Correlation - Statistics
# * One way to measure the strength of the correlation between continuous numeric variable is by using a method called `Pearson Correlation`.
# * The `Pearson Correlation` method will give you two values:
#     1. `Correlation Coefficient`: For the coorelation coefficient, a value close to 1 implies a large positive correlation, a value close to -1 implies a large negative correlation, and a value close to 0 implies no correlation between the two variables.
#     2. `P-value`: The P-value tells us how certain we are about the correlation between the two variables. Generally, a `P-value less than 0.001` gives us `strong certainty` about the correlation coefficient that we calculated, a value `between 0.001 and 0.05` gives us `moderate certainty`, a `P-value between 0.05 and 0.1` gives us `weak certainty` and a `P-value larger than 0.1` will give us `no certainty` about the correlation coefficient that we calculated.

# %%
df['horsepower'] = df['horsepower'].astype(float)
mean_hp = df['horsepower'].mean()
df['horsepower'].replace(np.nan, mean_hp, inplace=True)
df['horsepower'].notnull().sum()
# Out:
# 205

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# symboling               int64
# normalized-losses      object
# make                   object
# fuel-type              object
# aspiration             object
# num-of-doors           object
# body-style             object
# drive-wheels           object
# engine-location        object
# wheel-base            float64
# length                float64
# width                 float64
# height                float64
# curb-weight             int64
# engine-type            object
# num-of-cylinders       object
# engine-size             int64
# fuel-system            object
# bore                   object
# stroke                 object
# compression-ratio     float64
# horsepower            float64
# peak-rpm               object
# city-L/100Km          float64
# highway-mpg             int64
# price                 float64
# price-binned         category
# dtype: object

# %%
df.dropna(subset=['price'], axis=0,inplace=True)

# %%
pears_coef, p_value = stats.pearsonr(df['horsepower'], df['price'])
pears_coef, p_value
# Out:
# (0.8095745670036559, 6.369057428259526e-48)

# %% [markdown]
# * Since the `pearson-coefficient` is close to `1` hence their is a strong positive correlation between `horsepower` and `price` the `P-value` is `<0.001`, this means that we are `certain` about the `positive correlation` between `horsepower` and `price`.

# %% [markdown]
# # Correlation Heatmap
# * A `correlation heatmap` is a `heatmap` that shows the `correlation matrix`.
# * Taking all variables into account, we can calculate the `correlation` between every pair of variables, `correlation` between pairs of variables is calculated using three methods:
#     1. `Pearson`: Standard correlation coefficient
#     2. `Kendall`: Kendall Tau correlation coefficient
#     3. `Spearman`: Spearman rank correlation coefficient
# * Each of these methods have their own strengths and weaknesses, and can be used in different scenarios.
# * To build a `correlation heatmap`, we first need to calculate the `correlation matrix` that contains the `correlation` between each pair of variables.
# * We can then plot the `correlation matrix` using a `heatmap`.

# %%
#First let us check about the missing values in categorical columns
df.isnull().sum()
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           0
# peak-rpm             2
# city-L/100Km         0
# highway-mpg          0
# price                0
# price-binned         0
# dtype: int64

# %% [markdown]
# As we can see there are some missing values in categorical columns. We have to handle these columns.
# * As we had learnied that we can change the data type of the columns. By this is only possible if data filled is in other data-type as in case of `normalized-losses`, `bore`, `stroke`, `horsepower`, `peak-rpm` and `price` columns.
# * But in case of `make` column, we have to replace the missing values with the most frequent value in the column.
# * We can use `value_counts()` method to find the most frequent value in the column.
# * We can use `replace()` method to replace the missing values with the most frequent value in the column.

# %%
#Let's first list of columns with pure object type values
cat_cols = ['make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'engine-type', 'num-of-cylinders', 'fuel-system', 'price-binned']
cat_cols
# Out:
# ['make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'engine-type',
#  'num-of-cylinders',
#  'fuel-system',
#  'price-binned']

# %%
#Making a list of columns with numerical type values
num_cols = ['symboling', 'normalized-losses', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-size', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-L/100Km', 'highway-mpg', 'price']
num_cols
# Out:
# ['symboling',
#  'normalized-losses',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-size',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-L/100Km',
#  'highway-mpg',
#  'price']

# %% [markdown]
# Now, first we have to fill missing data in categorical columns. For this we have `SimpleImputer` class in `sklearn.impute` module.
# * `SimpleImputer` class provides basic strategies for imputing missing values, either using the `mean`, `median` or `most frequent` value of the column in which the missing values are located.
# * We can use `SimpleImputer` class to replace the missing values with the most frequent value in the column.

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imputer.fit(df[cat_cols])
df[cat_cols] = imputer.transform(df[cat_cols])

# %%
# Let's check if there are any missing values in the categorical columns
def fill_na(col):
    df[col] = df[col].astype(float)
    mean = df[col].mean()
    df[col].replace(np.nan, mean, inplace=True)
    return df[col]

# %%
for col in num_cols:
    col = fill_na(col)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-L/100Km         0
# highway-mpg          0
# price                0
# price-binned         0
# dtype: int64

# %% [markdown]
# * Now for plotting heatmap chart first we have to encode all the catagorical columns into numerical data.
# * For this we can use `encoders` from `sklearn` library.
# * There are basically three types of encoders:
#     1. `Label Encoder`: It is used to encode the catagorical data into numerical data when .
#     2. `One Hot Encoder`: It is used to encode the catagorical data into numerical data and create dummy variables for each catagory.
#     3. `Ordinal Encoders`: It is used to encode the catagorical data into numerical data when the catagories have some order.

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
for col in cat_cols:
    df[col] = encoder.fit_transform(df[col])

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# symboling            float64
# normalized-losses    float64
# make                   int32
# fuel-type              int32
# aspiration             int32
# num-of-doors           int32
# body-style             int32
# drive-wheels           int32
# engine-location        int32
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight          float64
# engine-type            int32
# num-of-cylinders       int32
# engine-size          float64
# fuel-system            int32
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-L/100Km         float64
# highway-mpg          float64
# price                float64
# price-binned           int32
# dtype: object

# %%
df.corrwith(df['price'])
# Out:
# Unnamed: 0          -0.117889
# symboling           -0.082391
# normalized-losses    0.133999
# make                -0.163646
# fuel-type           -0.110326
# aspiration           0.179578
# num-of-doors        -0.042435
# body-style          -0.072933
# drive-wheels         0.588333
# engine-location      0.331062
# wheel-base           0.584642
# length               0.690628
# width                0.751265
# height               0.135486
# curb-weight          0.834415
# engine-type          0.126025
# num-of-cylinders     0.005509
# engine-size          0.872335
# fuel-system          0.521689
# bore                 0.543154
# stroke               0.082267
# compression-ratio    0.071107
# horsepower           0.809575
# peak-rpm            -0.101542
# city-L/100Km         0.789898
# highway-mpg         -0.704692
# price                1.000000
# price-binned        -0.165769
# dtype: float64

# %%
# Now we are ready to generate heatmap
plt.figure(figsize=(25,15))
matrix = np.triu(df.corr())
sns.heatmap(df.corr(), annot=True, mask=matrix)
# Out:
# <Axes: >

# %% [markdown]
# # Model Development
# - A model or estimator can be thought of as a mathematical equation used to predict a value given one or more other values.
# - Relating one or more independent variables to a dependent variable.
# - Usually the more relevant data we have the more accurate our model is.
# - To understand why more data is important, consider the following situation:
#     * We have two almost identical cars.
#     * We want to use our mode to determine the price of two cars, one is pink car and other is red.
#     * If our model's independent variable or feature does not include color, our model will predict the same price for both cars.
#     * If our model's independent variable or feature does include color, our model will predict a higher price for the red car than the pink car.

# %% [markdown]
# ## Liner Regression and Multiple Regression
# * `Linear Regression` wil refer ti one independent variable to make a prediction.
# * `Multiple Regression` will refer to two or more independent variables to make a prediction.
# * `Simple Linear Regression (SLR)` is a method to help us understand the relationship between two variables:
#     * The predictor/independent variable (X)
#     * The response/dependent variable (that we want to predict)(Y)
# * The result of Linear Regression is a `linear function` that predicts the response (dependent) variable as a function of the predictor (independent) variable.
# * `Y: Response/Target/Dependent Variable`
# * `X: Predictor/Independent Variable`
# * `Y = b0 + b1X`
# * `b0: Intercept`
# * `b1: Slope`

# %% [markdown]
# In many cases, many factors influence how much people pay for a car, for example, how old the car is?
# - This uncertainty is represented by the error term, also called the `noise`.
# - The `noise` is the part of the data that can not be explained by the model, because there are other variables that influence the price that have not been included in the model.
# - The `noise` is the difference between the true value of the dependent variable, and the predicted value of the dependent variable.
# - It can be removed by using `residual plot`.

# %% [markdown]
# # Model Evaluation using visualization
# * `Regression plot` are good extimate of:
#     - The relationship between two variable.
#     - The strength of correlation and
#     - The direction of the relationship.
#
# * The horizontal axis is the independent variable and the vertical axis is the dependent variables.
# * Each point on the graph represents a different target points.
# * The fitted line represents the predicted value.
# * There are several ways to plot a `regression plot` a simple way to use `Regplot` from the `seaborn` library.

# %%
# Regression Plot
def plot_regression(x, y):
    sns.regplot(x=x, y=y, data=df)
    plt.ylim(0,)
    plt.show()

# %%
# Splitting the dataset into independent and dependent variables
x = df.drop('price', axis=1) # Independent variable
y = df['price'] # Dependent variable

# %%
for col in x:
    plot_regression(x[col], y)

# %% [markdown]
# - From the above graphs we can say that the some of the data columns are showing us a linear relationship with the target variable and some are not.
# - So we have to select the columns which are showing linear relationship with the target variable.

# %% [markdown]
# ## Residual Plot
# - A `residual plot` is a graph that shows the residuals on the vertical axis and the independent variable on the horizontal axis.
# - If the points in a `residual plot` are randomly spread out around the x-axis, then a `linear model` is appropriate for the data.
# - Randomly spread out residuals means that the variance is constant, and thus the linear model is a good fit for this data.

# %%
# Residual Plot
def plot_residual(x, y):
    sns.residplot(x=x, y=y, data=df)
    plt.show()

# %%
for col in x:
    plot_residual(x[col], y)

# %% [markdown]
# So, we can say that the `wheel-base`, '`lenght`, `width`, `curb-weight`, `engine-size`, `bore`, `city-l/100Km`, `horsepower` and `highway-mpg` are the best predictor variables for the `price` target variable.

# %% [markdown]
# # Distribution Plot
# * A distribution plot counts the actual values versus the predicted value.
# * These plot are extremely useful for visualizing models with more than one independent variables or features.
# * We can plot the distribution plot using `distplot()` function from `seaborn` library.
# * We can plot the distribution plot using `matplotlib` library.

# %%
# Distribution Plot
import matplotlib.pyplot as plt
def plot_distribution(x):
    plt.figure(figsize=(10,5))
    sns.distplot(df[x], hist=True, kde=True, color='red')
    plt.show()

# %%
for col in x:
    plot_distribution(col)
# Out:
# C:\Users\Navneet\AppData\Local\Temp\ipykernel_10280\949024740.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[x], hist=True, kde=True, color='red')
# C:\Users\Navneet\AppData\Local\Temp\ipykernel_10280\949024740.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# We can summarize the process like this:
# - We have a set of training points. We use these training point to fit and train the model and get parameter.
# - We then use these parameter in the model to predict the value of the target variable.
# - We then compare the predicted value with the actual value to see how accurate our model is.
# - We then use the test data to evaluate the model.

# %% [markdown]
# To fit the model in Python, we import `Linear Model` from `sklearn` library.
# - We then create a `linear regression` object.
# - We define the `predictor` and `target` variables.
# - We then fit the model using `fit()` method.
# - We then use `predict()` method to predict the value of the target variable.

# %%
from sklearn.linear_model import LinearRegression
X = df[['highway-mpg']]
Y = df['price']
lm = LinearRegression()
lm.fit(X,Y)
lm.predict(X)
# Out:
# array([16236.50464347, 16236.50464347, 17058.23802179, 13771.3045085 ,
#        20345.17153508, 17879.97140011, 17879.97140011, 17879.97140011,
#        21988.63829172, 14593.03788682, 14593.03788682, 15414.77126514,
#        15414.77126514, 17879.97140011, 20345.17153508, 20345.17153508,
#        21988.63829172, -5128.5631929 ,  3088.77059031,  3088.77059031,
#         4732.23734696,  7197.43748192, 13771.3045085 ,  7197.43748192,
#         7197.43748192,  7197.43748192, 13771.3045085 , 13771.3045085 ,
#        18701.70477843, -5950.29657123,  7197.43748192,  3910.50396864,
#        10484.37099521, 10484.37099521, 10484.37099521, 10484.37099521,
#        11306.10437353, 11306.10437353, 11306.10437353, 11306.10437353,
#        15414.77126514, 12949.57113018, 14593.03788682, 14593.03788682,
#        22810.37167004, 22810.37167004, 24453.83842668, 12949.57113018,
#         7197.43748192,  7197.43748192,  7197.43748192,  7197.43748192,
# ...

# %% [markdown]
# Now, lets see how accurate our model is.
# * R-squared is a measure to indicate how close the data is to the fitted regression line.
# * The value of the R-squared is the percentage of variation of the response variable (y) that is explained by a linear model.
# * The closer the R-squared to 1, the better the model fits your data.
# * The closer the R-squared to 0, the worse the model fits your data.

# %%
# Calculating the R^2 value
lm.score(X,Y)
# Out:
# 0.4965911884339176

# %% [markdown]
# Mean Squared Error (MSE) is the mean of the squared errors:
# * The difference between each predicted value and the actual value.
# * It's always non-negative.
# * Values closer to zero are better.

# %%
# Calculating the MSE
from sklearn.metrics import mean_squared_error
y_pred = lm.predict(X)
mean_squared_error(Y, y_pred)
# Out:
# 31635042.944639888

# %% [markdown]
# Root Mean Squared Error (RMSE) is the square root of the mean of the squared errors:
# * It shows how spread out the errors are.
# * It's always non-negative.
# * Values closer to zero are better.

# %%
# Calculating the RMSE
from math import sqrt
sqrt(mean_squared_error(Y, y_pred))
# Out:
# 5624.503795415191

# %% [markdown]
# - Mean Absolute Error (MAE) is the mean of the absolute value of the errors:
# * It shows how close the predictions are to the actual values.
# * It's always non-negative.
# * Values closer to zero are better.

# %%
# Calculating the MAE
from sklearn.metrics import mean_absolute_error
mean_absolute_error(Y, y_pred)
# Out:
# 4054.9931281284407

# %% [markdown]
# As we can see that instead of having accuracy of 49% our model has high error rate. So we have to improve or change or model.
# # Multiple Linear Regression
# - Multiple Linear Regression is very similar to Simple Linear Regression, but this method is used to explain the relationship between one continuous response (dependent) variable and two or more predictor (independent) variables.
# - Most of the real-world regression models involve multiple predictors. We can use all of the predictors to create a model that predicts the response variable based on the predictors.
# - The equation is given by:
#     * `Y: Response/Target/Dependent Variable`
#     * `X: Predictor/Independent Variable`
#     * `Y = b0 + b1X1 + b2X2 + b3X3 + ... + bnXn`
#     * `b0: Intercept`
#     * `b1: Slope`

# %%
X = df[['wheel-base', 'length', 'width', 'curb-weight', 'engine-size', 'bore', 'horsepower', 'city-L/100Km', 'highway-mpg']]
Y = df['price']
lm = LinearRegression()
lm.fit(X,Y)
lm.predict(X)
# Out:
# array([12244.83162305, 12244.83162305, 18685.05920571, 10829.35127675,
#        16466.29113506, 15409.0614387 , 18805.04883404, 19150.4157068 ,
#        20254.13910579, 10487.08910176, 10487.08910176, 17295.42507992,
#        17468.1085163 , 18638.37285576, 27204.87805089, 27883.76441202,
#        31012.46037822,  2677.4959508 ,  6148.2564238 ,  6071.09254573,
#         5544.51951339,  6171.92573735,  8682.46786739,  6457.63833208,
#         6526.71170663,  6526.71170663,  8880.26889452, 11710.34850966,
#        18195.58091985,  7506.74307665,  6432.98336426,  5088.29293604,
#         6240.76619858,  6291.00138007,  5919.06391289,  6315.1551217 ,
#         9411.76479027,  9578.16882896,  9115.70521956,  7931.8546818 ,
#         9745.10570141, 10536.8195111 ,  7392.11647549, 11378.5129794 ,
#        35444.36371765, 35444.36371765, 45010.67654335,  4119.47840614,
#         6329.62579469,  6345.32428891,  5974.25338077,  5977.61127636,
# ...

# %%
# Calculating the R^2 value
lm.score(X,Y)
# Out:
# 0.8332005239451465

# %%
# Calculating the MSE
from sklearn.metrics import mean_squared_error
y_pred = lm.predict(X)
mean_squared_error(Y, y_pred)
# Out:
# 10481955.156333309

# %%
# Calculating the RMSE
from math import sqrt
sqrt(mean_squared_error(Y, y_pred))
# Out:
# 3237.5847720690354

# %%
# Calculating the MAE
from sklearn.metrics import mean_absolute_error
mean_absolute_error(Y, y_pred)
# Out:
# 2244.3310406887585
